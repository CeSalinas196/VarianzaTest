# %% [markdown]
# # UNAH
# ## Facultad de Ingenieria
# ## Carrera de Ingenieria en sistemas
# ### Clase: Inteligencia Artificial
#
# *Prueba*

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Segun el siguiente Dataset:

# %%
pd_vector = pd.DataFrame( { "num" : range(1,101) } )

# %%
pd_vector
# Out:
#     num
# 0     1
# 1     2
# 2     3
# 3     4
# 4     5
# ..  ...
# 95   96
# 96   97
# 97   98
# 98   99
# 99  100
#
# [100 rows x 1 columns]

# %% [markdown]
# Y segun los siguientes metodos de numpy

# %%
np.var( pd_vector["num"] ) ## Calcula la varianza
# Out:
# 833.25

# %%
np.std( pd_vector["num"] ) ## Calcula la desviacion estandard
# Out:
# 28.86607004772212

# %% [markdown]
# ## Responda las siguientes ejercicios

# %% [markdown]
# 1. Grafique el Boxplot del vector "num"

# %%
pd_vector.boxplot()

# %% [markdown]
# 2. Calcule la varianza y desviacion estandard de cada uno de los quartiles
#
# Nota: realice manual la divicion del dataset para obtener cada uno de quartiles, al final obtendra cuatro dataframes

# %%
'''Q1 = int( (np.mean(pd_vector["num"] +1 )/ 2) ) +1
Q2 = int(np.mean(pd_vector["num"])) + 1
Q3 = Q1 + Q2 - 1
Q4 = Q3 + Q1 - 1

Dfq1 = pd.DataFrame({ "num" : range(1,Q1)})
Dfq2 = pd.DataFrame({ "num" : range(1,Q2)})
Dfq3 = pd.DataFrame({ "num" : range(1,Q3)})
Dfq4 = pd.DataFrame({ "num" : range(1,Q4)})
'''
Q1 = int( (np.mean(pd_vector["num"] +1 )/ 2) )
Q2 = int(np.mean(pd_vector["num"]))
Q3 = Q1 + Q2

dfq1 = pd_vector.head(Q1)
dfq2 = pd_vector.head(Q2)
dfq3 = pd_vector.head(Q3)
dfq4 = pd_vector

# %% [markdown]
# 3. Explique la respuesta que obtuvo en el ejercicio dos, recuerde que se puede apoyar del grafico del ejercicio uno para hacer referencias sobre distribucion en caso de que sea necesario.

# %%
df1 = pd.DataFrame(pd_vector["num"])
df1.quantile([0,0.25,0.50,1])
# Out:
#          num
# 0.00    1.00
# 0.25   25.75
# 0.50   50.50
# 1.00  100.00
